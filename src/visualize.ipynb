# %%
import pandas as pd
import numpy as np

train_data = pd.read_excel("Data/tr.xlsx")

# %%
train_y = pd.DataFrame(train_data['outcome']) 
train_X = pd.DataFrame(train_data.drop(['outcome'],axis=1))

# %%
import tools
feature_kind = tools.init_feature_kind(train_X)
cont,cate = tools.get_feature_kind(train_X,feature_kind)

# %%
print(len(cont))
# Out:
# 24

# %%
import seaborn as sns
fig, ax =plt.subplots(3,8,figsize=(25,10))

for ind,feat in enumerate(cont) :  
    sns.histplot(data=train_X, x=feat,ax = ax[int(ind/8),int(ind%8)])

# %%
import tools 
tools.set_pandas_display_options()
train_X[cont].describe().T.to_csv('cont_des.csv')

# %%
print(len(cate))

import seaborn as sns
fig, ax =plt.subplots(4,11,figsize=(25,15))

for ind,feat in enumerate(cate) :  
    sns.countplot(data=train_X, x=feat,ax = ax[int(ind/11),int(ind%11)])
# Out:
# 43

# %%
train_X[cate].astype('object').describe().T.to_csv('cate_dis.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

g = sns.FacetGrid(train_data, col="outcome")
for feat in cont :  
    g.map(sns.histplot, feat)
    plt.show()
